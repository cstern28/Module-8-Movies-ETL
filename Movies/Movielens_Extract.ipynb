# %%
import pandas as pd

# %%
movies_metadata = pd.read_csv(f'{file_dir}movies_metadata.csv', low_memory=False)
ratings = pd.read_csv(f'{file_dir}ratings.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26396/1452940966.py in <module>
# ----> 1 movies_metadata = pd.read_csv(f'{file_dir}movies_metadata.csv', low_memory=False)
#       2 ratings = pd.read_csv(f'{file_dir}ratings.csv')
#
# NameError: name 'file_dir' is not defined

# %%
movies_metadata.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
movies_metadata.sample(n=5)
# Out:
#        adult                              belongs_to_collection   budget  \
# 16367  False                                                NaN        0
# 34376  False                                                NaN  2023012
# 35798  False  {'id': 158365, 'name': 'Why We Fight', 'poster...        0
# 2792   False                                                NaN  2000000
# 45348  False                                                NaN        0
#
#                                                   genres  \
# 16367  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 34376  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 35798                [{'id': 99, 'name': 'Documentary'}]
# 2792   [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 45348  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                          homepage      id    imdb_id  \
# 16367                                         NaN   56448  tt0105462
# 34376                                         NaN  314371  tt3865478
# 35798                                         NaN  159849  tt0173769
# 2792   http://www.foxsearchlight.com/boysdontcry/     226  tt0171804
# 45348                                         NaN   44918  tt1640571
#
#       original_language                    original_title  \
# 16367                en                            Stalin
# 34376                pl                          11 Minut
# 35798                en  Why We Fight: Divide and Conquer
# 2792                 en                    Boys Don't Cry
# 45348                en                        Titanic II
#
#                                                 overview  ... release_date  \
# 16367  The life and career of the brutal Soviet dicta...  ...   1992-11-21
# 34376  The lives of urbanites intertwine in a world w...  ...   2015-09-02
# 35798  The third film of Frank Capra's 'Why We Fight"...  ...   1943-01-01
# 2792   Female born, Teena Brandon adopts his male ide...  ...   1999-09-02
# 45348  On the 100th anniversary of the original voyag...  ...   2010-08-07
#
#           revenue runtime                                   spoken_languages  \
# 16367         0.0   166.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 34376         0.0    81.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 35798         0.0    57.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2792   11540607.0   118.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 45348         0.0    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 16367  Released                                                NaN
# 34376  Released                                                NaN
# 35798  Released                                                NaN
# 2792   Released  A true story about finding the courage to be y...
# 45348  Released           100 years later, lightning strikes twice
#
#                                   title  video vote_average vote_count
# 16367                            Stalin  False          5.3       17.0
# 34376                        11 Minutes  False          5.9       15.0
# 35798  Why We Fight: Divide and Conquer  False          5.0        1.0
# 2792                     Boys Don't Cry  False          7.2      360.0
# 45348                         Titanic 2  False          3.4       55.0
#
# [5 rows x 24 columns]

# %%
ratings.sample(n=5)
# Out:
#           userId  movieId  rating   timestamp
# 13397352  139277    98809     4.5  1490461234
# 2075700    21583     3753     3.0   998036156
# 19627298  203908      485     3.0   848494702
# 19408192  201537     1193     5.0   949383069
# 6004637    61804      494     3.0  1263617052

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26396/3412598449.py in <module>
# ----> 1 wiki_movies_df = pd.DataFrame(wiki_movies_raw)
#
# NameError: name 'wiki_movies_raw' is not defined
